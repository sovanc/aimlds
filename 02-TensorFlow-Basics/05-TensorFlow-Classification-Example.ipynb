# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0407 06:41:03.430414 140061006546688 estimator.py:1802] Using temporary folder as model directory: /tmp/tmpl9ywgk6q

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# W0407 06:41:07.429087 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/training_util.py:238: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0407 06:41:07.463540 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0407 06:41:07.469332 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0407 06:41:07.957305 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/linear.py:300: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0407 06:41:08.482162 140061006546688 deprecation.py:506] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/slot_creator.py:187: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0407 06:41:09.191440 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py:866: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.

# %%
# Useful link for your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# W0407 06:41:14.357978 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0407 06:41:14.887306 140061006546688 metrics_impl.py:803] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0407 06:41:14.921292 140061006546688 metrics_impl.py:803] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0407 06:41:15.130987 140061006546688 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
results
# Out:
# {'accuracy': 0.72047246,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7858077,
#  'auc_precision_recall': 0.6244135,
#  'average_loss': 0.5341026,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2177715,
#  'precision': 0.597561,
#  'prediction/mean': 0.3745354,
#  'recall': 0.5632184}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5294163], dtype=float32),
#   'logits': array([0.11780131], dtype=float32),
#   'probabilities': array([0.47058368, 0.5294163 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63749295], dtype=float32),
#   'logits': array([0.5644994], dtype=float32),
#   'probabilities': array([0.36250702, 0.63749295], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3941803], dtype=float32),
#   'logits': array([-0.42977405], dtype=float32),
#   'probabilities': array([0.6058197, 0.3941803], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32114157], dtype=float32),
#   'logits': array([-0.7485305], dtype=float32),
#   'probabilities': array([0.6788584 , 0.32114157], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1431798], dtype=float32),
#   'logits': array([-1.7891266], dtype=float32),
#   'probabilities': array([0.85682017, 0.14317983], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69749415], dtype=float32),
#   'logits': array([0.83539355], dtype=float32),
#   'probabilities': array([0.30250585, 0.69749415], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5999217], dtype=float32),
#   'logits': array([0.40513885], dtype=float32),
#   'probabilities': array([0.4000783, 0.5999217], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34992588], dtype=float32),
#   'logits': array([-0.6193651], dtype=float32),
#   'probabilities': array([0.6500741 , 0.34992585], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24365701], dtype=float32),
#   'logits': array([-1.1327333], dtype=float32),
#   'probabilities': array([0.75634295, 0.24365702], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24226311], dtype=float32),
#   'logits': array([-1.1403118], dtype=float32),
#   'probabilities': array([0.75773686, 0.24226311], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12925008], dtype=float32),
#   'logits': array([-1.9076056], dtype=float32),
#   'probabilities': array([0.87074995, 0.1292501 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15432978], dtype=float32),
#   'logits': array([-1.7010376], dtype=float32),
#   'probabilities': array([0.8456702 , 0.15432979], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31400448], dtype=float32),
#   'logits': array([-0.78146374], dtype=float32),
#   'probabilities': array([0.68599546, 0.31400448], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5913329], dtype=float32),
#   'logits': array([0.36947834], dtype=float32),
#   'probabilities': array([0.4086671, 0.5913329], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17201552], dtype=float32),
#   'logits': array([-1.5714097], dtype=float32),
#   'probabilities': array([0.82798445, 0.17201552], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3348565], dtype=float32),
#   'logits': array([-0.68630064], dtype=float32),
#   'probabilities': array([0.6651435, 0.3348565], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38451925], dtype=float32),
#   'logits': array([-0.47040993], dtype=float32),
#   'probabilities': array([0.6154808 , 0.38451922], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12876135], dtype=float32),
#   'logits': array([-1.9119555], dtype=float32),
#   'probabilities': array([0.87123865, 0.12876132], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3790683], dtype=float32),
#   'logits': array([-0.49350482], dtype=float32),
#   'probabilities': array([0.62093174, 0.37906826], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13677894], dtype=float32),
#   'logits': array([-1.8423048], dtype=float32),
#   'probabilities': array([0.86322105, 0.13677892], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21750462], dtype=float32),
#   'logits': array([-1.280268], dtype=float32),
#   'probabilities': array([0.7824954, 0.2175046], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30595177], dtype=float32),
#   'logits': array([-0.8191141], dtype=float32),
#   'probabilities': array([0.6940483 , 0.30595174], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6644515], dtype=float32),
#   'logits': array([0.6831955], dtype=float32),
#   'probabilities': array([0.3355485 , 0.66445154], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2172018], dtype=float32),
#   'logits': array([-1.2820481], dtype=float32),
#   'probabilities': array([0.78279823, 0.2172018 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1805847], dtype=float32),
#   'logits': array([-1.5123911], dtype=float32),
#   'probabilities': array([0.8194153, 0.1805847], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78528893], dtype=float32),
#   'logits': array([1.2967587], dtype=float32),
#   'probabilities': array([0.21471104, 0.78528893], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18692592], dtype=float32),
#   'logits': array([-1.4701099], dtype=float32),
#   'probabilities': array([0.81307405, 0.1869259 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3109855], dtype=float32),
#   'logits': array([-0.79551613], dtype=float32),
#   'probabilities': array([0.68901455, 0.31098548], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10179944], dtype=float32),
#   'logits': array([-2.177389], dtype=float32),
#   'probabilities': array([0.89820063, 0.10179944], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5966132], dtype=float32),
#   'logits': array([0.39137316], dtype=float32),
#   'probabilities': array([0.40338677, 0.5966132 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.94808817], dtype=float32),
#   'logits': array([2.9048994], dtype=float32),
#   'probabilities': array([0.0519119, 0.9480881], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41916817], dtype=float32),
#   'logits': array([-0.3261891], dtype=float32),
#   'probabilities': array([0.5808318 , 0.41916817], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31182417], dtype=float32),
#   'logits': array([-0.79160494], dtype=float32),
#   'probabilities': array([0.6881758 , 0.31182414], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58247495], dtype=float32),
#   'logits': array([0.33294165], dtype=float32),
#   'probabilities': array([0.41752505, 0.58247495], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25012445], dtype=float32),
#   'logits': array([-1.0979487], dtype=float32),
#   'probabilities': array([0.74987555, 0.25012445], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38522583], dtype=float32),
#   'logits': array([-0.4674253], dtype=float32),
#   'probabilities': array([0.61477417, 0.38522583], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52618724], dtype=float32),
#   'logits': array([0.10484481], dtype=float32),
#   'probabilities': array([0.47381273, 0.5261872 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6544054], dtype=float32),
#   'logits': array([0.63846076], dtype=float32),
#   'probabilities': array([0.34559456, 0.6544054 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75898165], dtype=float32),
#   'logits': array([1.1471045], dtype=float32),
#   'probabilities': array([0.24101835, 0.75898165], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33145443], dtype=float32),
#   'logits': array([-0.70161426], dtype=float32),
#   'probabilities': array([0.6685456 , 0.33145446], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18558252], dtype=float32),
#   'logits': array([-1.4789737], dtype=float32),
#   'probabilities': array([0.81441754, 0.18558247], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5543439], dtype=float32),
#   'logits': array([0.21823764], dtype=float32),
#   'probabilities': array([0.4456561, 0.5543439], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1539503], dtype=float32),
#   'logits': array([-1.7039483], dtype=float32),
#   'probabilities': array([0.84604967, 0.1539503 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5493296], dtype=float32),
#   'logits': array([0.19796228], dtype=float32),
#   'probabilities': array([0.45067042, 0.5493296 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14141291], dtype=float32),
#   'logits': array([-1.8036036], dtype=float32),
#   'probabilities': array([0.858587  , 0.14141296], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10542011], dtype=float32),
#   'logits': array([-2.1384006], dtype=float32),
#   'probabilities': array([0.8945799 , 0.10542013], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61239076], dtype=float32),
#   'logits': array([0.4573729], dtype=float32),
#   'probabilities': array([0.38760924, 0.61239076], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18521056], dtype=float32),
#   'logits': array([-1.4814364], dtype=float32),
#   'probabilities': array([0.8147895 , 0.18521057], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20901325], dtype=float32),
#   'logits': array([-1.3308836], dtype=float32),
#   'probabilities': array([0.7909868 , 0.20901324], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11687578], dtype=float32),
#   'logits': array([-2.0223544], dtype=float32),
#   'probabilities': array([0.88312423, 0.11687577], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16648018], dtype=float32),
#   'logits': array([-1.6107812], dtype=float32),
#   'probabilities': array([0.83351976, 0.16648017], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25440407], dtype=float32),
#   'logits': array([-1.0752603], dtype=float32),
#   'probabilities': array([0.745596, 0.254404], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2508461], dtype=float32),
#   'logits': array([-1.094105], dtype=float32),
#   'probabilities': array([0.749154 , 0.2508461], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3882048], dtype=float32),
#   'logits': array([-0.45486456], dtype=float32),
#   'probabilities': array([0.6117952 , 0.38820478], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13157883], dtype=float32),
#   'logits': array([-1.8870704], dtype=float32),
#   'probabilities': array([0.86842114, 0.13157886], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21937752], dtype=float32),
#   'logits': array([-1.2692976], dtype=float32),
#   'probabilities': array([0.7806225 , 0.21937752], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20947611], dtype=float32),
#   'logits': array([-1.328086], dtype=float32),
#   'probabilities': array([0.7905239 , 0.20947614], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21455139], dtype=float32),
#   'logits': array([-1.2977058], dtype=float32),
#   'probabilities': array([0.78544855, 0.21455137], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5024326], dtype=float32),
#   'logits': array([0.00973034], dtype=float32),
#   'probabilities': array([0.49756747, 0.5024326 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15825295], dtype=float32),
#   'logits': array([-1.6712848], dtype=float32),
#   'probabilities': array([0.84174705, 0.15825295], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23884255], dtype=float32),
#   'logits': array([-1.1590357], dtype=float32),
#   'probabilities': array([0.76115745, 0.23884255], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66559935], dtype=float32),
#   'logits': array([0.68834805], dtype=float32),
#   'probabilities': array([0.33440065, 0.6655993 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6399324], dtype=float32),
#   'logits': array([0.57507074], dtype=float32),
#   'probabilities': array([0.36006764, 0.63993245], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51347417], dtype=float32),
#   'logits': array([0.05390966], dtype=float32),
#   'probabilities': array([0.48652586, 0.51347417], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34892404], dtype=float32),
#   'logits': array([-0.6237722], dtype=float32),
#   'probabilities': array([0.651076, 0.348924], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49805233], dtype=float32),
#   'logits': array([-0.00779068], dtype=float32),
#   'probabilities': array([0.50194764, 0.49805233], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1759727], dtype=float32),
#   'logits': array([-1.5438749], dtype=float32),
#   'probabilities': array([0.8240273 , 0.17597269], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19646287], dtype=float32),
#   'logits': array([-1.4085499], dtype=float32),
#   'probabilities': array([0.80353713, 0.19646287], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15857677], dtype=float32),
#   'logits': array([-1.6688559], dtype=float32),
#   'probabilities': array([0.8414233 , 0.15857679], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12970765], dtype=float32),
#   'logits': array([-1.9035461], dtype=float32),
#   'probabilities': array([0.87029237, 0.12970766], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61437154], dtype=float32),
#   'logits': array([0.46572554], dtype=float32),
#   'probabilities': array([0.38562843, 0.61437154], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23788029], dtype=float32),
#   'logits': array([-1.1643362], dtype=float32),
#   'probabilities': array([0.76211977, 0.23788029], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43662417], dtype=float32),
#   'logits': array([-0.25487417], dtype=float32),
#   'probabilities': array([0.56337583, 0.43662417], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5904983], dtype=float32),
#   'logits': array([0.36602592], dtype=float32),
#   'probabilities': array([0.40950167, 0.5904984 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2946746], dtype=float32),
#   'logits': array([-0.87278765], dtype=float32),
#   'probabilities': array([0.7053254 , 0.29467458], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6644062], dtype=float32),
#   'logits': array([0.6829922], dtype=float32),
#   'probabilities': array([0.3355938, 0.6644062], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12562913], dtype=float32),
#   'logits': array([-1.94017], dtype=float32),
#   'probabilities': array([0.8743708 , 0.12562917], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6200745], dtype=float32),
#   'logits': array([0.4898647], dtype=float32),
#   'probabilities': array([0.37992546, 0.62007457], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12220072], dtype=float32),
#   'logits': array([-1.9717531], dtype=float32),
#   'probabilities': array([0.8777993, 0.1222007], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56601024], dtype=float32),
#   'logits': array([0.26559126], dtype=float32),
#   'probabilities': array([0.43398976, 0.56601024], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34318793], dtype=float32),
#   'logits': array([-0.64911985], dtype=float32),
#   'probabilities': array([0.6568121, 0.3431879], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16745451], dtype=float32),
#   'logits': array([-1.6037762], dtype=float32),
#   'probabilities': array([0.8325455, 0.1674545], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5612362], dtype=float32),
#   'logits': array([0.24618077], dtype=float32),
#   'probabilities': array([0.43876374, 0.5612362 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6005959], dtype=float32),
#   'logits': array([0.40794873], dtype=float32),
#   'probabilities': array([0.39940408, 0.60059595], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5720303], dtype=float32),
#   'logits': array([0.29013968], dtype=float32),
#   'probabilities': array([0.42796966, 0.5720303 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17237473], dtype=float32),
#   'logits': array([-1.5688896], dtype=float32),
#   'probabilities': array([0.8276253 , 0.17237474], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3661225], dtype=float32),
#   'logits': array([-0.5488877], dtype=float32),
#   'probabilities': array([0.6338775, 0.3661225], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1545938], dtype=float32),
#   'logits': array([-1.6990162], dtype=float32),
#   'probabilities': array([0.8454062 , 0.15459378], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7183169], dtype=float32),
#   'logits': array([0.9361279], dtype=float32),
#   'probabilities': array([0.28168318, 0.7183169 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8259344], dtype=float32),
#   'logits': array([1.5570834], dtype=float32),
#   'probabilities': array([0.17406556, 0.8259344 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6235988], dtype=float32),
#   'logits': array([0.5048517], dtype=float32),
#   'probabilities': array([0.37640122, 0.6235989 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21302897], dtype=float32),
#   'logits': array([-1.3067634], dtype=float32),
#   'probabilities': array([0.7869711 , 0.21302895], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44902617], dtype=float32),
#   'logits': array([-0.20460624], dtype=float32),
#   'probabilities': array([0.5509739, 0.4490262], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38627717], dtype=float32),
#   'logits': array([-0.46298826], dtype=float32),
#   'probabilities': array([0.61372286, 0.38627717], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46011436], dtype=float32),
#   'logits': array([-0.1598823], dtype=float32),
#   'probabilities': array([0.53988564, 0.46011433], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34966183], dtype=float32),
#   'logits': array([-0.6205262], dtype=float32),
#   'probabilities': array([0.65033823, 0.3496618 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.452786], dtype=float32),
#   'logits': array([-0.18942034], dtype=float32),
#   'probabilities': array([0.54721403, 0.452786  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16032895], dtype=float32),
#   'logits': array([-1.6557827], dtype=float32),
#   'probabilities': array([0.8396711 , 0.16032894], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5687075], dtype=float32),
#   'logits': array([0.27657974], dtype=float32),
#   'probabilities': array([0.4312925, 0.5687075], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5724771], dtype=float32),
#   'logits': array([0.29196477], dtype=float32),
#   'probabilities': array([0.42752293, 0.5724771 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24525025], dtype=float32),
#   'logits': array([-1.1241071], dtype=float32),
#   'probabilities': array([0.7547498 , 0.24525025], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18133724], dtype=float32),
#   'logits': array([-1.5073137], dtype=float32),
#   'probabilities': array([0.81866276, 0.18133724], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17676726], dtype=float32),
#   'logits': array([-1.538405], dtype=float32),
#   'probabilities': array([0.8232327 , 0.17676726], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2741922], dtype=float32),
#   'logits': array([-0.97345597], dtype=float32),
#   'probabilities': array([0.7258078 , 0.27419218], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40178767], dtype=float32),
#   'logits': array([-0.39802206], dtype=float32),
#   'probabilities': array([0.59821236, 0.40178764], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13658309], dtype=float32),
#   'logits': array([-1.8439643], dtype=float32),
#   'probabilities': array([0.8634169, 0.1365831], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33257675], dtype=float32),
#   'logits': array([-0.69655377], dtype=float32),
#   'probabilities': array([0.66742325, 0.33257672], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.229433], dtype=float32),
#   'logits': array([-1.2115155], dtype=float32),
#   'probabilities': array([0.770567  , 0.22943301], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09879887], dtype=float32),
#   'logits': array([-2.2106423], dtype=float32),
#   'probabilities': array([0.9012011 , 0.09879886], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12146829], dtype=float32),
#   'logits': array([-1.9785988], dtype=float32),
#   'probabilities': array([0.8785317 , 0.12146828], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7514576], dtype=float32),
#   'logits': array([1.1064012], dtype=float32),
#   'probabilities': array([0.24854243, 0.7514576 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18103158], dtype=float32),
#   'logits': array([-1.5093739], dtype=float32),
#   'probabilities': array([0.8189684, 0.1810316], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1336233], dtype=float32),
#   'logits': array([-1.8692949], dtype=float32),
#   'probabilities': array([0.86637664, 0.13362333], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14197424], dtype=float32),
#   'logits': array([-1.7989886], dtype=float32),
#   'probabilities': array([0.8580257 , 0.14197423], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5029783], dtype=float32),
#   'logits': array([0.01191342], dtype=float32),
#   'probabilities': array([0.49702168, 0.5029783 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48699293], dtype=float32),
#   'logits': array([-0.0520401], dtype=float32),
#   'probabilities': array([0.5130071 , 0.48699293], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24155295], dtype=float32),
#   'logits': array([-1.1441845], dtype=float32),
#   'probabilities': array([0.75844705, 0.24155289], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4440132], dtype=float32),
#   'logits': array([-0.22489029], dtype=float32),
#   'probabilities': array([0.5559868, 0.4440132], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18258081], dtype=float32),
#   'logits': array([-1.4989592], dtype=float32),
#   'probabilities': array([0.8174192, 0.1825808], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22503403], dtype=float32),
#   'logits': array([-1.2365674], dtype=float32),
#   'probabilities': array([0.77496594, 0.22503406], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5106405], dtype=float32),
#   'logits': array([0.04256833], dtype=float32),
#   'probabilities': array([0.48935956, 0.5106405 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4986624], dtype=float32),
#   'logits': array([-0.00535035], dtype=float32),
#   'probabilities': array([0.5013376 , 0.49866244], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14211306], dtype=float32),
#   'logits': array([-1.7978492], dtype=float32),
#   'probabilities': array([0.8578869 , 0.14211309], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.408392], dtype=float32),
#   'logits': array([-0.37061667], dtype=float32),
#   'probabilities': array([0.5916079 , 0.40839198], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.697371], dtype=float32),
#   'logits': array([0.83481014], dtype=float32),
#   'probabilities': array([0.30262896, 0.69737107], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5556586], dtype=float32),
#   'logits': array([0.22356081], dtype=float32),
#   'probabilities': array([0.44434142, 0.5556586 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40966994], dtype=float32),
#   'logits': array([-0.36533004], dtype=float32),
#   'probabilities': array([0.59033006, 0.40966994], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55764914], dtype=float32),
#   'logits': array([0.23162675], dtype=float32),
#   'probabilities': array([0.4423508 , 0.55764914], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22541827], dtype=float32),
#   'logits': array([-1.2343656], dtype=float32),
#   'probabilities': array([0.77458173, 0.22541825], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19415201], dtype=float32),
#   'logits': array([-1.4232537], dtype=float32),
#   'probabilities': array([0.80584794, 0.19415201], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13378865], dtype=float32),
#   'logits': array([-1.8678675], dtype=float32),
#   'probabilities': array([0.86621135, 0.13378866], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26843098], dtype=float32),
#   'logits': array([-1.0025979], dtype=float32),
#   'probabilities': array([0.73156905, 0.26843092], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49090648], dtype=float32),
#   'logits': array([-0.03637815], dtype=float32),
#   'probabilities': array([0.5090935 , 0.49090645], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6975216], dtype=float32),
#   'logits': array([0.83552384], dtype=float32),
#   'probabilities': array([0.30247834, 0.6975216 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22320348], dtype=float32),
#   'logits': array([-1.2470945], dtype=float32),
#   'probabilities': array([0.77679646, 0.22320348], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16173661], dtype=float32),
#   'logits': array([-1.6453633], dtype=float32),
#   'probabilities': array([0.83826345, 0.1617366 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41952372], dtype=float32),
#   'logits': array([-0.32472885], dtype=float32),
#   'probabilities': array([0.5804763 , 0.41952375], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23516676], dtype=float32),
#   'logits': array([-1.179363], dtype=float32),
#   'probabilities': array([0.7648333 , 0.23516674], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14801203], dtype=float32),
#   'logits': array([-1.7502788], dtype=float32),
#   'probabilities': array([0.85198796, 0.14801203], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1826255], dtype=float32),
#   'logits': array([-1.4986597], dtype=float32),
#   'probabilities': array([0.81737447, 0.1826255 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12422454], dtype=float32),
#   'logits': array([-1.9530189], dtype=float32),
#   'probabilities': array([0.87577546, 0.12422455], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38617647], dtype=float32),
#   'logits': array([-0.46341318], dtype=float32),
#   'probabilities': array([0.6138236 , 0.38617644], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78618085], dtype=float32),
#   'logits': array([1.3020563], dtype=float32),
#   'probabilities': array([0.21381916, 0.78618085], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7761724], dtype=float32),
#   'logits': array([1.2434988], dtype=float32),
#   'probabilities': array([0.22382757, 0.77617246], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5558821], dtype=float32),
#   'logits': array([0.22446609], dtype=float32),
#   'probabilities': array([0.44411793, 0.5558821 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5078746], dtype=float32),
#   'logits': array([0.03150094], dtype=float32),
#   'probabilities': array([0.49212536, 0.50787455], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58079386], dtype=float32),
#   'logits': array([0.32603323], dtype=float32),
#   'probabilities': array([0.41920608, 0.58079386], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1169062], dtype=float32),
#   'logits': array([-2.0220597], dtype=float32),
#   'probabilities': array([0.88309383, 0.11690618], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5460363], dtype=float32),
#   'logits': array([0.1846683], dtype=float32),
#   'probabilities': array([0.45396367, 0.5460363 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7688059], dtype=float32),
#   'logits': array([1.201581], dtype=float32),
#   'probabilities': array([0.23119408, 0.7688059 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41616276], dtype=float32),
#   'logits': array([-0.33854586], dtype=float32),
#   'probabilities': array([0.5838373 , 0.41616276], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27560085], dtype=float32),
#   'logits': array([-0.9663891], dtype=float32),
#   'probabilities': array([0.7243992 , 0.27560082], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36473435], dtype=float32),
#   'logits': array([-0.55487406], dtype=float32),
#   'probabilities': array([0.63526565, 0.3647343 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59659576], dtype=float32),
#   'logits': array([0.39130056], dtype=float32),
#   'probabilities': array([0.40340427, 0.59659576], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24233532], dtype=float32),
#   'logits': array([-1.1399186], dtype=float32),
#   'probabilities': array([0.7576647 , 0.24233532], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6631757], dtype=float32),
#   'logits': array([0.67747855], dtype=float32),
#   'probabilities': array([0.33682433, 0.66317576], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41103387], dtype=float32),
#   'logits': array([-0.3596931], dtype=float32),
#   'probabilities': array([0.58896613, 0.41103384], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42830706], dtype=float32),
#   'logits': array([-0.28876173], dtype=float32),
#   'probabilities': array([0.57169294, 0.42830703], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1679789], dtype=float32),
#   'logits': array([-1.6000195], dtype=float32),
#   'probabilities': array([0.8320211, 0.1679789], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18792538], dtype=float32),
#   'logits': array([-1.4635472], dtype=float32),
#   'probabilities': array([0.8120746 , 0.18792538], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1845659], dtype=float32),
#   'logits': array([-1.485714], dtype=float32),
#   'probabilities': array([0.8154341 , 0.18456592], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.443188], dtype=float32),
#   'logits': array([-0.22823358], dtype=float32),
#   'probabilities': array([0.556812  , 0.44318798], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15280107], dtype=float32),
#   'logits': array([-1.7127986], dtype=float32),
#   'probabilities': array([0.8471989 , 0.15280108], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7305664], dtype=float32),
#   'logits': array([0.99749804], dtype=float32),
#   'probabilities': array([0.26943362, 0.7305664 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20803717], dtype=float32),
#   'logits': array([-1.3367977], dtype=float32),
#   'probabilities': array([0.7919628 , 0.20803715], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50912726], dtype=float32),
#   'logits': array([0.03651321], dtype=float32),
#   'probabilities': array([0.49087268, 0.50912726], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15586475], dtype=float32),
#   'logits': array([-1.6893241], dtype=float32),
#   'probabilities': array([0.8441353 , 0.15586476], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6766957], dtype=float32),
#   'logits': array([0.7386279], dtype=float32),
#   'probabilities': array([0.32330427, 0.67669576], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.322933], dtype=float32),
#   'logits': array([-0.74032545], dtype=float32),
#   'probabilities': array([0.67706704, 0.322933  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1902689], dtype=float32),
#   'logits': array([-1.4482639], dtype=float32),
#   'probabilities': array([0.8097311, 0.1902689], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35892043], dtype=float32),
#   'logits': array([-0.58005285], dtype=float32),
#   'probabilities': array([0.64107955, 0.3589204 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3313306], dtype=float32),
#   'logits': array([-0.7021731], dtype=float32),
#   'probabilities': array([0.6686694, 0.3313306], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16114083], dtype=float32),
#   'logits': array([-1.6497641], dtype=float32),
#   'probabilities': array([0.83885914, 0.16114083], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7215661], dtype=float32),
#   'logits': array([0.9522433], dtype=float32),
#   'probabilities': array([0.2784339 , 0.72156614], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.192797], dtype=float32),
#   'logits': array([-1.4319373], dtype=float32),
#   'probabilities': array([0.807203, 0.192797], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16615427], dtype=float32),
#   'logits': array([-1.6131318], dtype=float32),
#   'probabilities': array([0.83384573, 0.16615427], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27119726], dtype=float32),
#   'logits': array([-0.9885566], dtype=float32),
#   'probabilities': array([0.7288027 , 0.27119726], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43711376], dtype=float32),
#   'logits': array([-0.2528841], dtype=float32),
#   'probabilities': array([0.56288624, 0.43711376], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27202395], dtype=float32),
#   'logits': array([-0.98437804], dtype=float32),
#   'probabilities': array([0.7279761 , 0.27202395], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11582912], dtype=float32),
#   'logits': array([-2.0325344], dtype=float32),
#   'probabilities': array([0.88417083, 0.11582912], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.84183884], dtype=float32),
#   'logits': array([1.6719737], dtype=float32),
#   'probabilities': array([0.15816121, 0.8418388 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6843443], dtype=float32),
#   'logits': array([0.7738091], dtype=float32),
#   'probabilities': array([0.3156557, 0.6843443], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53286946], dtype=float32),
#   'logits': array([0.13166773], dtype=float32),
#   'probabilities': array([0.46713054, 0.53286946], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73481035], dtype=float32),
#   'logits': array([1.0191672], dtype=float32),
#   'probabilities': array([0.26518968, 0.73481035], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11317238], dtype=float32),
#   'logits': array([-2.0587382], dtype=float32),
#   'probabilities': array([0.88682765, 0.11317241], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1468454], dtype=float32),
#   'logits': array([-1.7595603], dtype=float32),
#   'probabilities': array([0.85315454, 0.14684542], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2067999], dtype=float32),
#   'logits': array([-1.344324], dtype=float32),
#   'probabilities': array([0.7932001 , 0.20679988], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33821595], dtype=float32),
#   'logits': array([-0.67125463], dtype=float32),
#   'probabilities': array([0.66178405, 0.33821598], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37596458], dtype=float32),
#   'logits': array([-0.50671226], dtype=float32),
#   'probabilities': array([0.6240355 , 0.37596458], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58548445], dtype=float32),
#   'logits': array([0.34532905], dtype=float32),
#   'probabilities': array([0.41451558, 0.58548445], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56419736], dtype=float32),
#   'logits': array([0.2582147], dtype=float32),
#   'probabilities': array([0.4358026 , 0.56419736], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.387936], dtype=float32),
#   'logits': array([-0.4559965], dtype=float32),
#   'probabilities': array([0.612064, 0.387936], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3726657], dtype=float32),
#   'logits': array([-0.52079785], dtype=float32),
#   'probabilities': array([0.62733436, 0.37266573], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3482442], dtype=float32),
#   'logits': array([-0.62676597], dtype=float32),
#   'probabilities': array([0.6517558 , 0.34824422], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1835517], dtype=float32),
#   'logits': array([-1.4924672], dtype=float32),
#   'probabilities': array([0.81644833, 0.18355171], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64320177], dtype=float32),
#   'logits': array([0.5892881], dtype=float32),
#   'probabilities': array([0.35679823, 0.64320177], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12790081], dtype=float32),
#   'logits': array([-1.9196482], dtype=float32),
#   'probabilities': array([0.8720992 , 0.12790081], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2625748], dtype=float32),
#   'logits': array([-1.0326287], dtype=float32),
#   'probabilities': array([0.73742515, 0.2625748 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54355973], dtype=float32),
#   'logits': array([0.17468178], dtype=float32),
#   'probabilities': array([0.45644024, 0.54355973], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36686358], dtype=float32),
#   'logits': array([-0.54569584], dtype=float32),
#   'probabilities': array([0.6331364 , 0.36686358], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19000238], dtype=float32),
#   'logits': array([-1.4499947], dtype=float32),
#   'probabilities': array([0.8099976 , 0.19000238], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27795333], dtype=float32),
#   'logits': array([-0.95463663], dtype=float32),
#   'probabilities': array([0.7220467 , 0.27795333], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26302582], dtype=float32),
#   'logits': array([-1.0303007], dtype=float32),
#   'probabilities': array([0.7369742, 0.2630258], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13398299], dtype=float32),
#   'logits': array([-1.8661919], dtype=float32),
#   'probabilities': array([0.86601704, 0.13398297], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18615696], dtype=float32),
#   'logits': array([-1.4751773], dtype=float32),
#   'probabilities': array([0.813843  , 0.18615696], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58252156], dtype=float32),
#   'logits': array([0.33313346], dtype=float32),
#   'probabilities': array([0.41747844, 0.5825216 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6850473], dtype=float32),
#   'logits': array([0.7770655], dtype=float32),
#   'probabilities': array([0.3149527, 0.6850473], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.638205], dtype=float32),
#   'logits': array([0.5675819], dtype=float32),
#   'probabilities': array([0.36179498, 0.63820505], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7042466], dtype=float32),
#   'logits': array([0.86760247], dtype=float32),
#   'probabilities': array([0.29575342, 0.7042466 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47352713], dtype=float32),
#   'logits': array([-0.10599053], dtype=float32),
#   'probabilities': array([0.52647287, 0.47352716], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29928055], dtype=float32),
#   'logits': array([-0.85072625], dtype=float32),
#   'probabilities': array([0.7007194 , 0.29928052], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51387304], dtype=float32),
#   'logits': array([0.05550635], dtype=float32),
#   'probabilities': array([0.486127  , 0.51387304], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18267432], dtype=float32),
#   'logits': array([-1.4983329], dtype=float32),
#   'probabilities': array([0.8173257, 0.1826743], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14610696], dtype=float32),
#   'logits': array([-1.7654667], dtype=float32),
#   'probabilities': array([0.853893, 0.146107], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18588108], dtype=float32),
#   'logits': array([-1.4769993], dtype=float32),
#   'probabilities': array([0.8141189, 0.1858811], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5149622], dtype=float32),
#   'logits': array([0.05986679], dtype=float32),
#   'probabilities': array([0.4850378 , 0.51496226], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06018025], dtype=float32),
#   'logits': array([-2.7483442], dtype=float32),
#   'probabilities': array([0.9398198 , 0.06018023], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29074997], dtype=float32),
#   'logits': array([-0.8917446], dtype=float32),
#   'probabilities': array([0.70925003, 0.2907499 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16383648], dtype=float32),
#   'logits': array([-1.6299553], dtype=float32),
#   'probabilities': array([0.8361635, 0.1638365], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2710344], dtype=float32),
#   'logits': array([-0.98938084], dtype=float32),
#   'probabilities': array([0.7289656, 0.2710344], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24085933], dtype=float32),
#   'logits': array([-1.1479741], dtype=float32),
#   'probabilities': array([0.75914073, 0.24085933], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27275902], dtype=float32),
#   'logits': array([-0.9806692], dtype=float32),
#   'probabilities': array([0.727241  , 0.27275902], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77770144], dtype=float32),
#   'logits': array([1.2523212], dtype=float32),
#   'probabilities': array([0.22229858, 0.77770144], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17765167], dtype=float32),
#   'logits': array([-1.5323395], dtype=float32),
#   'probabilities': array([0.82234836, 0.17765166], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12352031], dtype=float32),
#   'logits': array([-1.9595077], dtype=float32),
#   'probabilities': array([0.8764797 , 0.12352034], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6009423], dtype=float32),
#   'logits': array([0.40939307], dtype=float32),
#   'probabilities': array([0.39905763, 0.6009423 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48407373], dtype=float32),
#   'logits': array([-0.06372666], dtype=float32),
#   'probabilities': array([0.51592624, 0.4840737 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.85467297], dtype=float32),
#   'logits': array([1.7717323], dtype=float32),
#   'probabilities': array([0.14532702, 0.8546729 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6422278], dtype=float32),
#   'logits': array([0.58504665], dtype=float32),
#   'probabilities': array([0.35777217, 0.6422278 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12559314], dtype=float32),
#   'logits': array([-1.9404981], dtype=float32),
#   'probabilities': array([0.8744068 , 0.12559314], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6443707], dtype=float32),
#   'logits': array([0.59438515], dtype=float32),
#   'probabilities': array([0.35562935, 0.6443707 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54581994], dtype=float32),
#   'logits': array([0.18379545], dtype=float32),
#   'probabilities': array([0.45418003, 0.54581994], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77978164], dtype=float32),
#   'logits': array([1.2643943], dtype=float32),
#   'probabilities': array([0.22021836, 0.77978164], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22965845], dtype=float32),
#   'logits': array([-1.2102408], dtype=float32),
#   'probabilities': array([0.7703415 , 0.22965842], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17287189], dtype=float32),
#   'logits': array([-1.5654088], dtype=float32),
#   'probabilities': array([0.8271282, 0.1728719], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5631785], dtype=float32),
#   'logits': array([0.25407195], dtype=float32),
#   'probabilities': array([0.4368215, 0.5631785], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15390998], dtype=float32),
#   'logits': array([-1.7042577], dtype=float32),
#   'probabilities': array([0.84608996, 0.15390998], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78123885], dtype=float32),
#   'logits': array([1.2729006], dtype=float32),
#   'probabilities': array([0.21876112, 0.7812389 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53724486], dtype=float32),
#   'logits': array([0.14925587], dtype=float32),
#   'probabilities': array([0.46275514, 0.53724486], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17637183], dtype=float32),
#   'logits': array([-1.5411248], dtype=float32),
#   'probabilities': array([0.8236282 , 0.17637183], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55615187], dtype=float32),
#   'logits': array([0.22555888], dtype=float32),
#   'probabilities': array([0.44384816, 0.55615187], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47077027], dtype=float32),
#   'logits': array([-0.11705244], dtype=float32),
#   'probabilities': array([0.52922976, 0.47077027], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1084744], dtype=float32),
#   'logits': array([-2.1064193], dtype=float32),
#   'probabilities': array([0.8915255 , 0.10847446], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5198489], dtype=float32),
#   'logits': array([0.07943738], dtype=float32),
#   'probabilities': array([0.48015106, 0.5198489 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6055715], dtype=float32),
#   'logits': array([0.4287349], dtype=float32),
#   'probabilities': array([0.39442843, 0.6055715 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74931157], dtype=float32),
#   'logits': array([1.0949442], dtype=float32),
#   'probabilities': array([0.25068837, 0.7493116 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8174444], dtype=float32),
#   'logits': array([1.4991279], dtype=float32),
#   'probabilities': array([0.18255563, 0.8174443 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44520688], dtype=float32),
#   'logits': array([-0.2200563], dtype=float32),
#   'probabilities': array([0.5547932 , 0.44520688], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16137871], dtype=float32),
#   'logits': array([-1.6480054], dtype=float32),
#   'probabilities': array([0.8386213 , 0.16137871], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08876257], dtype=float32),
#   'logits': array([-2.3288383], dtype=float32),
#   'probabilities': array([0.91123736, 0.08876257], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10697009], dtype=float32),
#   'logits': array([-2.1220708], dtype=float32),
#   'probabilities': array([0.8930299 , 0.10697009], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2552179], dtype=float32),
#   'logits': array([-1.070974], dtype=float32),
#   'probabilities': array([0.7447821 , 0.25521788], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3248409], dtype=float32),
#   'logits': array([-0.7316128], dtype=float32),
#   'probabilities': array([0.6751591, 0.3248409], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27447355], dtype=float32),
#   'logits': array([-0.9720427], dtype=float32),
#   'probabilities': array([0.72552645, 0.27447355], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# W0407 06:41:24.969877 140061006546688 estimator.py:1802] Using temporary folder as model directory: /tmp/tmpuil4oexo

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-cea30273f6d4> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     358
#     359       saving_listeners = _check_listeners_type(saving_listeners)
# --> 360       loss = self._train_model(input_fn, hooks, saving_listeners)
#     361       logging.info('Loss for final step: %s.', loss)
#     362       return self
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1138       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1139     else:
# -> 1140       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1141
#    1142   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1168       worker_hooks.extend(input_hooks)
#    1169       estimator_spec = self._call_model_fn(
# -> 1170           features, labels, ModeKeys.TRAIN, self.config)
#    1171       global_step_tensor = training_util.get_global_step(g)
#    1172       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1126
#    1127     logging.info('Calling model_fn.')
# -> 1128     model_fn_results = self._model_fn(features=features, **kwargs)
#    1129     logging.info('Done calling model_fn.')
#    1130
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     744           input_layer_partitioner=input_layer_partitioner,
#     745           config=config,
# --> 746           batch_norm=batch_norm)
#     747
#     748     super(DNNClassifier, self).__init__(
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     461         input_layer_partitioner=input_layer_partitioner,
#     462         batch_norm=batch_norm)
# --> 463     logits = logit_fn(features=features, mode=mode)
#     464
#     465     return _get_dnn_estimator_spec(use_tpu, head, features, labels, mode,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#     102         input_layer_partitioner,
#     103         batch_norm,
# --> 104         name='dnn')
#     105     return dnn_model(features, mode)
#     106
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     181     if feature_column_lib.is_feature_column_v2(feature_columns):
#     182       self._input_layer = feature_column_lib.DenseFeatures(
# --> 183           feature_columns=feature_columns, name='input_layer')
#     184     else:
#     185       self._input_layer = feature_column.InputLayer(
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#     436         name=name,
#     437         expected_column_type=DenseColumn,
# --> 438         **kwargs)
#     439
#     440   @property
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     336             'You can wrap a categorical column with an '
#     337             'embedding_column or indicator_column. Given: {}'.format(
# --> 338                 expected_column_type, column))
#     339
#     340   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Marcial\AppData\Local\Temp\tmp2csebpzn
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\Marcial\\AppData\\Local\\Temp\\tmp2csebpzn', '_save_summary_steps': 100, '_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Marcial\AppData\Local\Temp\tmp2csebpzn\model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into C:\Users\Marcial\AppData\Local\Temp\tmp2csebpzn\model.ckpt.
# INFO:tensorflow:loss = 3.74969, step = 1001
# INFO:tensorflow:global_step/sec: 274.17
# INFO:tensorflow:loss = 6.46712, step = 1101 (0.365 sec)
# INFO:tensorflow:global_step/sec: 297.713
# INFO:tensorflow:loss = 3.54156, step = 1201 (0.336 sec)
# INFO:tensorflow:global_step/sec: 293.387
# INFO:tensorflow:loss = 4.90772, step = 1301 (0.341 sec)
# INFO:tensorflow:global_step/sec: 279.777
# INFO:tensorflow:loss = 4.02881, step = 1401 (0.356 sec)
# INFO:tensorflow:global_step/sec: 298.946
# INFO:tensorflow:loss = 7.81228, step = 1501 (0.336 sec)
# INFO:tensorflow:global_step/sec: 292.626
# INFO:tensorflow:loss = 4.58984, step = 1601 (0.341 sec)
# INFO:tensorflow:global_step/sec: 277.284
# INFO:tensorflow:loss = 7.23425, step = 1701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 278.78
# INFO:tensorflow:loss = 2.29589, step = 1801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 268.195
# INFO:tensorflow:loss = 4.46603, step = 1901 (0.374 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into C:\Users\Marcial\AppData\Local\Temp\tmp2csebpzn\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.92565.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-08-30-00:04:32
# INFO:tensorflow:Restoring parameters from C:\Users\Marcial\AppData\Local\Temp\tmp2csebpzn\model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-08-30-00:04:33
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.716535, accuracy_baseline = 0.65748, auc = 0.813132, auc_precision_recall = 0.674242, average_loss = 0.525238, global_step = 2000, label/mean = 0.34252, loss = 5.13117, prediction/mean = 0.356299
# {'accuracy': 0.71653545,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.81313235,
#  'auc_precision_recall': 0.67424196,
#  'average_loss': 0.52523774,
#  'global_step': 2000,
#  'label/mean': 0.34251967,
#  'loss': 5.1311688,
#  'prediction/mean': 0.35629925}

# %% [markdown]
# # Great Job!
